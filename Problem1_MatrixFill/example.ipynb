# %%
from matrix_filler import fill_matrix_with_constraints
import numpy as np

#Try any matrix you want, does not need to be a square matrix
grid = np.array([
    [2, np.nan,np.nan, 3.0],
    [np.nan, 1, np.nan, np.nan],
    [np.nan, np.nan, 4, np.nan],
    [3, np.nan, np.nan, 1]
])

#Try any row and column targets you want
row_targets = np.array([10, 10, 10])
col_targets = np.array([10, 10, 10, 10])

filled_grid, result = fill_matrix_with_constraints(grid, row_targets, col_targets,non_negative=True)

print(filled_grid)
print(result)
# Out:
# [[2.         4.41428571 2.01428571 3.        ]
#  [4.18571429 1.         2.55714286 3.68571429]
#  [2.38571429 3.15714286 4.         1.88571429]]
#        message: The unconstrained solution is optimal.
#        success: True
#         status: 3
#            fun: [ 1.429e+00  1.429e+00  1.429e+00 -1.429e+00 -1.429e+00
#                  -1.429e+00 -1.429e+00]
#              x: [ 4.414e+00  2.014e+00  4.186e+00  2.557e+00  3.686e+00
#                   2.386e+00  3.157e+00  1.886e+00]
#            nit: 0
#           cost: 7.142857142857141
#     optimality: 1.7763568394002505e-14
#    active_mask: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00  0.000e+00
#                   0.000e+00  0.000e+00  0.000e+00]
#  unbounded_sol: (array([ 4.414e+00,  2.014e+00,  4.186e+00,  2.557e+00,
#                         3.686e+00,  2.386e+00,  3.157e+00,  1.886e+00]), array([], dtype=float64), 6, array([ 2.205e+00,  1.902e+00,  1.804e+00,  1.414e+00,
#                         1.176e+00,  9.408e-01,  1.029e-16]))
